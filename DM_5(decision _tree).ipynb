# %%
from sklearn import datasets
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from matplotlib import pyplot as plt

# %%
cancer = datasets.load_breast_cancer()
X= cancer.data
y=cancer.target

# %%
clf = DecisionTreeClassifier(criterion='entropy',max_depth=None,random_state=0)
model=clf.fit(X,y)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_22 <= 105.95
# |   |--- feature_27 <= 0.14
# |   |   |--- feature_13 <= 48.98
# |   |   |   |--- feature_21 <= 30.15
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_21 >  30.15
# |   |   |   |   |--- feature_21 <= 30.27
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_21 >  30.27
# |   |   |   |   |   |--- feature_24 <= 0.14
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_24 >  0.14
# |   |   |   |   |   |   |--- feature_24 <= 0.14
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_24 >  0.14
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_13 >  48.98
# |   |   |   |--- feature_8 <= 0.17
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_8 >  0.17
# |   |   |   |   |--- class: 1
# |   |--- feature_27 >  0.14
# |   |   |--- feature_21 <= 27.58
# |   |   |   |--- feature_28 <= 0.36
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_28 >  0.36
# |   |   |   |   |--- feature_23 <= 446.20
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_23 >  446.20
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_21 >  27.58
# |   |   |   |--- class: 0
# |--- feature_22 >  105.95
# |   |--- feature_22 <= 117.45
# |   |   |--- feature_24 <= 0.14
# |   |   |   |--- feature_21 <= 25.67
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_21 >  25.67
# |   |   |   |   |--- feature_29 <= 0.07
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_29 >  0.07
# |   |   |   |   |   |--- feature_20 <= 16.88
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_20 >  16.88
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_24 >  0.14
# |   |   |   |--- feature_21 <= 17.53
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_21 >  17.53
# |   |   |   |   |--- class: 0
# |   |--- feature_22 >  117.45
# |   |   |--- feature_19 <= 0.00
# |   |   |   |--- feature_6 <= 0.07
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_6 >  0.07
# |   |   |   |   |--- class: 0
# |   |   |--- feature_19 >  0.00
# |   |   |   |--- class: 0

# %%
with open("decision_tree.log","w") as fout:
  fout.write(text_representation)

# %%
fig = plt.figure(figsize=(25,15))
tree.plot_tree(clf,feature_names = cancer.feature_names,class_names=cancer.target_names,filled=True)
# Out:
# [Text(753.3, 764.4375, 'worst perimeter <= 105.95\nentropy = 0.953\nsamples = 569\nvalue = [212, 357]\nclass = benign'),
#  Text(418.5, 662.5125, 'worst concave points <= 0.135\nentropy = 0.283\nsamples = 345\nvalue = [17, 328]\nclass = benign'),
#  Text(223.2, 560.5875, 'area error <= 48.975\nentropy = 0.097\nsamples = 320\nvalue = [4, 316]\nclass = benign'),
#  Text(111.6, 458.66249999999997, 'worst texture <= 30.145\nentropy = 0.055\nsamples = 316\nvalue = [2, 314]\nclass = benign'),
#  Text(55.8, 356.7375, 'entropy = 0.0\nsamples = 274\nvalue = [0, 274]\nclass = benign'),
#  Text(167.39999999999998, 356.7375, 'worst texture <= 30.265\nentropy = 0.276\nsamples = 42\nvalue = [2, 40]\nclass = benign'),
#  Text(111.6, 254.8125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(223.2, 254.8125, 'worst smoothness <= 0.141\nentropy = 0.165\nsamples = 41\nvalue = [1, 40]\nclass = benign'),
#  Text(167.39999999999998, 152.88750000000005, 'entropy = 0.0\nsamples = 33\nvalue = [0, 33]\nclass = benign'),
#  Text(279.0, 152.88750000000005, 'worst smoothness <= 0.144\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]\nclass = benign'),
#  Text(223.2, 50.96249999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(334.79999999999995, 50.96249999999998, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = benign'),
#  Text(334.79999999999995, 458.66249999999997, 'mean symmetry <= 0.166\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]\nclass = malignant'),
#  Text(279.0, 356.7375, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = malignant'),
#  Text(390.59999999999997, 356.7375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(613.8, 560.5875, 'worst texture <= 27.575\nentropy = 0.999\nsamples = 25\nvalue = [13, 12]\nclass = malignant'),
#  Text(558.0, 458.66249999999997, 'worst symmetry <= 0.358\nentropy = 0.811\nsamples = 16\nvalue = [4, 12]\nclass = benign'),
#  Text(502.2, 356.7375, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]\nclass = benign'),
#  Text(613.8, 356.7375, 'worst area <= 446.2\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]\nclass = malignant'),
#  Text(558.0, 254.8125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(669.5999999999999, 254.8125, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = malignant'),
#  Text(669.5999999999999, 458.66249999999997, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = malignant'),
#  Text(1088.1, 662.5125, 'worst perimeter <= 117.45\nentropy = 0.556\nsamples = 224\nvalue = [195, 29]\nclass = malignant'),
#  Text(892.8, 560.5875, 'worst smoothness <= 0.136\nentropy = 0.998\nsamples = 57\nvalue = [30, 27]\nclass = malignant'),
#  Text(781.1999999999999, 458.66249999999997, 'worst texture <= 25.67\nentropy = 0.787\nsamples = 34\nvalue = [8, 26]\nclass = benign'),
#  Text(725.4, 356.7375, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = benign'),
#  Text(837.0, 356.7375, 'worst fractal dimension <= 0.07\nentropy = 0.985\nsamples = 14\nvalue = [8, 6]\nclass = malignant'),
#  Text(781.1999999999999, 254.8125, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = malignant'),
#  Text(892.8, 254.8125, 'worst radius <= 16.875\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]\nclass = benign'),
#  Text(837.0, 152.88750000000005, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6]\nclass = benign'),
#  Text(948.5999999999999, 152.88750000000005, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = malignant'),
#  Text(1004.4, 458.66249999999997, 'worst texture <= 17.53\nentropy = 0.258\nsamples = 23\nvalue = [22, 1]\nclass = malignant'),
#  Text(948.5999999999999, 356.7375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(1060.2, 356.7375, 'entropy = 0.0\nsamples = 22\nvalue = [22, 0]\nclass = malignant'),
#  Text(1283.3999999999999, 560.5875, 'fractal dimension error <= 0.002\nentropy = 0.094\nsamples = 167\nvalue = [165, 2]\nclass = malignant'),
#  Text(1227.6, 458.66249999999997, 'mean concavity <= 0.067\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]\nclass = benign'),
#  Text(1171.8, 356.7375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(1283.3999999999999, 356.7375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(1339.1999999999998, 458.66249999999997, 'entropy = 0.0\nsamples = 164\nvalue = [164, 0]\nclass = malignant')]

# %%
fig.savefig("decisiontree.png")

# %%
cancer =  load_breast_cancer()
X_train , X_test , y_train , y_test = train_test_split(cancer.data,cancer.target,test_size=0.3,random_state=0)
tree = DecisionTreeClassifier(random_state = 0)
tree.fit(X_train , y_train)
print("Accracy on Training Set : {:.3f}".format(tree.score(X_train,y_train)))
print("Accuracy on Testing Set : {:,3f}",format(tree.score(X_test,y_test)))
# Out:
# Accracy on Training Set : 1.000
# Accuracy on Testing Set : {:,3f} 0.9122807017543859

# %%
tree = DecisionTreeClassifier(max_depth = 4 , random_state = 0)
tree.fit(X_train , y_train)
print("Accracy on Training Set : {:.3f}".format(tree.score(X_train,y_train)))
print("Accuracy on Testing Set : {:.3f}".format(tree.score(X_test,y_test)))
# Out:
# Accracy on Training Set : 0.977
# Accuracy on Testing Set : 0.947
